# %%
dbutils.fs.ls("/Volumes/workspace/foodlens/raw_files/")

# %%
chicago_df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/foodlens/raw_files/Chicago_RawData.csv")
chicago_df.printSchema()
print(f"Row count: {chicago_df.count()}")
chicago_df.show(3, truncate=False)

# %%
dallas_df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/foodlens/raw_files/Dallas_RawData.csv")
dallas_df.printSchema()
print(f"Row count: {dallas_df.count()}")
dallas_df.show(3, truncate=False)

# %%
CATALOG = "workspace"

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.foodlens_bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.foodlens_silver")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.foodlens_gold")

print("Schemas created:")
spark.sql(f"SHOW SCHEMAS IN {CATALOG}").show()
