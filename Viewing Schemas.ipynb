# %%
spark.table("workspace.foodlens_silver.chicago_inspections").printSchema()

# %%
spark.table("workspace.foodlens_silver.dallas_inspections").printSchema()

# %%
spark.table("workspace.foodlens_silver.chicago_violations").printSchema()

# %%
spark.table("workspace.foodlens_silver.dallas_violations").printSchema()
